# %% [markdown]
# Installing dependencies & loading data
#
# First, we install spaCy (to train the model), sklearn (to split the data for training), and tqdm (for a nice progress bar).

# %%
#Install libraries
# !pip install spacy sklearn tqdm

import spacy
#Show what version of spaCy
print(f'Using spaCy version {spacy.__version__}')
# Out:
# ...
# Using spaCy version 3.5.3

# %% [markdown]
# Next, we creat a list of the text files in the litbank/entities/brat directory and display the number of texts.

# %% [markdown]
# **Process the text**
#
# Here, we run each of the text files through spaCy. We add the annotations of different entities.

# %%
nlp = spacy.load("es_core_news_lg")
#nlp = spacy.blank("es")

#obras = ['682320','703753','681868','681846','703747', 'dioses']
obras = ['dioses','tisbe','cloris','flora','zeus']
text = ''
for id in obras:
    with open('../texto-obras/' + id + "-train.txt") as f:
        text += f.read()

print(text)
 
corpus = []

doc = nlp(text)
for sent in doc.sents:
    corpus.append(sent.text)

nlp = spacy.blank("es")
ruler = nlp.add_pipe("entity_ruler")

patterns = [
                # deidades y mitos
                {"label": "MIT", "pattern": "Hipogrifo"},
                {"label": "MIT", "pattern": "Faetonte"},
                {"label": "MIT", "pattern": "Flora"},
                {"label": "MIT", "pattern": "Hero"},
                {"label": "MIT", "pattern": "Lamia"},
                {"label": "MIT", "pattern": "Tisbe"},
                {"label": "MIT", "pattern": "Píramo"},
                {"label": "MIT", "pattern": "Zeus"},
    
                # wikidata dioses griegos
                {"label": "MIT", "pattern": "Hécate"},{"label": "MIT", "pattern": "Selene"},{"label": "MIT", "pattern": "Pan"},{"label": "MIT", "pattern": "Helios"},{"label": "MIT", "pattern": "Eris"},{"label": "MIT", "pattern": "Zagreo"},{"label": "MIT", "pattern": "Adonis"},{"label": "MIT", "pattern": "Eón"},{"label": "MIT", "pattern": "Niké"},{"label": "MIT", "pattern": "Eolo"},{"label": "MIT", "pattern": "Ponos"},{"label": "MIT", "pattern": "Eos"},{"label": "MIT", "pattern": "Anfítrite"},{"label": "MIT", "pattern": "oceánide"},{"label": "MIT", "pattern": "Iris"},{"label": "MIT", "pattern": "Equidna"},{"label": "MIT", "pattern": "Némesis"},{"label": "MIT", "pattern": "Circe"},{"label": "MIT", "pattern": "Cibeles"},{"label": "MIT", "pattern": "Zelo"},{"label": "MIT", "pattern": "Hipnos"},{"label": "MIT", "pattern": "Hemera"},{"label": "MIT", "pattern": "Tánatos"},{"label": "MIT", "pattern": "Orión"},{"label": "MIT", "pattern": "Higía"},{"label": "MIT", "pattern": "Hermafrodito"},{"label": "MIT", "pattern": "Pluto"},{"label": "MIT", "pattern": "Ate"},{"label": "MIT", "pattern": "Serapis"},{"label": "MIT", "pattern": "Irene"},{"label": "MIT", "pattern": "Bía"},{"label": "MIT", "pattern": "Adefagia"},{"label": "MIT", "pattern": "Eleos"},{"label": "MIT", "pattern": "Adranos"},{"label": "MIT", "pattern": "Agatodemon"},{"label": "MIT", "pattern": "Agdistis"},{"label": "MIT", "pattern": "Aristeo"},{"label": "MIT", "pattern": "Q395236"},{"label": "MIT", "pattern": "Aidos"},{"label": "MIT", "pattern": "Egeón"},{"label": "MIT", "pattern": "Momo"},{"label": "MIT", "pattern": "Dice"},{"label": "MIT", "pattern": "Himeneo"},{"label": "MIT", "pattern": "Anteros"},{"label": "MIT", "pattern": "Apate"},{"label": "MIT", "pattern": "Afea"},{"label": "MIT", "pattern": "Croto"},{"label": "MIT", "pattern": "Proioxis"},{"label": "MIT", "pattern": "Karneios"},{"label": "MIT", "pattern": "Carpo"},{"label": "MIT", "pattern": "Eufrósine"},{"label": "MIT", "pattern": "Yaco"},{"label": "MIT", "pattern": "Palioxis"},{"label": "MIT", "pattern": "Aspis"},{"label": "MIT", "pattern": "Astrea"},{"label": "MIT", "pattern": "Enio"},{"label": "MIT", "pattern": "Athena Chalcioecus"},{"label": "MIT", "pattern": "Harpócrates"},{"label": "MIT", "pattern": "Auxo"},{"label": "MIT", "pattern": "Bendis"},{"label": "MIT", "pattern": "Bentesicime"},{"label": "MIT", "pattern": "Soter"},{"label": "MIT", "pattern": "Psique"},{"label": "MIT", "pattern": "Panacea"},{"label": "MIT", "pattern": "Eunomia"},{"label": "MIT", "pattern": "Brizo"},{"label": "MIT", "pattern": "Maris"},{"label": "MIT", "pattern": "Fantaso"},{"label": "MIT", "pattern": "Thyia"},{"label": "MIT", "pattern": "Poros"},{"label": "MIT", "pattern": "Filotes"},{"label": "MIT", "pattern": "Harmonía"},{"label": "MIT", "pattern": "Geras"},{"label": "MIT", "pattern": "Moro"},{"label": "MIT", "pattern": "Pandia"},{"label": "MIT", "pattern": "Lisa"},{"label": "MIT", "pattern": "Theandrios"},{"label": "MIT", "pattern": "Traso"},{"label": "MIT", "pattern": "Espermo"},{"label": "MIT", "pattern": "Hipta"},{"label": "MIT", "pattern": "Oberon"},{"label": "MIT", "pattern": "Aeolus"},{"label": "MIT", "pattern": "Limos"},{"label": "MIT", "pattern": "Artemis of Ephesus"},{"label": "MIT", "pattern": "Homados"},{"label": "MIT", "pattern": "Lype"},{"label": "MIT", "pattern": "Acratus"},{"label": "MIT", "pattern": "Ctesius"},{"label": "MIT", "pattern": "Oeno"},{"label": "MIT", "pattern": "Opora"},{"label": "MIT", "pattern": "Amphiona"},{"label": "MIT", "pattern": "Basile"},{"label": "MIT", "pattern": "Euthymia"},{"label": "MIT", "pattern": "Scelmis"},{"label": "MIT", "pattern": "Conisalus"},{"label": "MIT", "pattern": "Titaea"},{"label": "MIT", "pattern": "Chthon"},{"label": "MIT", "pattern": "Eupraxia"},{"label": "MIT", "pattern": "Corymbus"},{"label": "MIT", "pattern": "Yoque"},{"label": "MIT", "pattern": "Aes"},{"label": "MIT", "pattern": "Biris"},{"label": "MIT", "pattern": "Orthanes"},{"label": "MIT", "pattern": "Caligenia"},{"label": "MIT", "pattern": "Euamerion"},{"label": "MIT", "pattern": "Euposia"},{"label": "MIT", "pattern": "Adrasteia"},{"label": "MIT", "pattern": "Tychon"},{"label": "MIT", "pattern": "Basileia"},{"label": "MIT", "pattern": "Aisa"},{"label": "MIT", "pattern": "Amicitia"},{"label": "MIT", "pattern": "Anivs"},{"label": "MIT", "pattern": "Auxesia"},{"label": "MIT", "pattern": "Apotropaei"},{"label": "MIT", "pattern": "Bonus Deus"},{"label": "MIT", "pattern": "Brauronia"},{"label": "MIT", "pattern": "Calumny"},{"label": "MIT", "pattern": "Dolor"},{"label": "MIT", "pattern": "Apollo Maleatas"},{"label": "MIT", "pattern": "Eurynome"},{"label": "MIT", "pattern": "Phobos and Deimos"},{"label": "MIT", "pattern": "Genetyllides"},{"label": "MIT", "pattern": "Amphissa of Locris"},{"label": "MIT", "pattern": "Athena Promachos"},{"label": "MIT", "pattern": "Demeter Eleusinia"},{"label": "MIT", "pattern": "Phoebus"},{"label": "MIT", "pattern": "Triclaria"},{"label": "MIT", "pattern": "Agathe Tyche"},{"label": "MIT", "pattern": "Athena Polias"},{"label": "MIT", "pattern": "Clymenus"},{"label": "MIT", "pattern": "Prodomeis"},{"label": "MIT", "pattern": "Nike"},{"label": "MIT", "pattern": "Stratius"},{"label": "MIT", "pattern": "Demokratia"},{"label": "MIT", "pattern": "Epikrateia"},{"label": "MIT", "pattern": "Malophorus"},{"label": "MIT", "pattern": "Acesis"},{"label": "MIT", "pattern": "Deima"},{"label": "MIT", "pattern": "Feme"},{"label": "MIT", "pattern": "Filomelo"},{"label": "MIT", "pattern": "Disnomia"},{"label": "MIT", "pattern": "Despoina"},{"label": "MIT", "pattern": "Damia"},{"label": "MIT", "pattern": "Dicaeosyne"},{"label": "MIT", "pattern": "Ossa"},{"label": "MIT", "pattern": "Dolos"},{"label": "MIT", "pattern": "Talo"},{"label": "MIT", "pattern": "Afrodito"},{"label": "MIT", "pattern": "Fusis"},{"label": "MIT", "pattern": "Sardus"},{"label": "MIT", "pattern": "Telesforo"},{"label": "MIT", "pattern": "Enialio"},{"label": "MIT", "pattern": "Sabacio"},{"label": "MIT", "pattern": "Oizís"},{"label": "MIT", "pattern": "Eunostus"},{"label": "MIT", "pattern": "Evonyme"},{"label": "MIT", "pattern": "Neaera"},{"label": "MIT", "pattern": "Hímero"},{"label": "MIT", "pattern": "Sosípolis"},{"label": "MIT", "pattern": "Ptono"},{"label": "MIT", "pattern": "Keltos"},{"label": "MIT", "pattern": "Galene"},{"label": "MIT", "pattern": "Nestis"},{"label": "MIT", "pattern": "Poto"},{"label": "MIT", "pattern": "Gynaikeia"},{"label": "MIT", "pattern": "Meiliquios"},{"label": "MIT", "pattern": "Hilates"},{"label": "MIT", "pattern": "Mise"},{"label": "MIT", "pattern": "Heósforo"},{"label": "MIT", "pattern": "Como"},{"label": "MIT", "pattern": "Kourótrofo"},{"label": "MIT", "pattern": "Peón"},{"label": "MIT", "pattern": "Nemea"},{"label": "MIT", "pattern": "Oreius"},{"label": "MIT", "pattern": "Palaemon"},{"label": "MIT", "pattern": "Pheme"},{"label": "MIT", "pattern": "Praxidike"},{"label": "MIT", "pattern": "Telemo"},{"label": "MIT", "pattern": "Thesmophoros"},{"label": "MIT", "pattern": "Elpis"},{"label": "MIT", "pattern": "Icelus"},{"label": "MIT", "pattern": "Cotis"},{"label": "MIT", "pattern": "Adicia"},{"label": "MIT", "pattern": "Angelos"},{"label": "MIT", "pattern": "Caerus"},{"label": "MIT", "pattern": "Poine"},{"label": "MIT", "pattern": "Ekecheiria"},{"label": "MIT", "pattern": "Melínoe"},{"label": "MIT", "pattern": "Macaria"},{"label": "MIT", "pattern": "Neikea"},{"label": "MIT", "pattern": "Euclea"},{"label": "MIT", "pattern": "Algos"},{"label": "MIT", "pattern": "Filofrósine"},{"label": "MIT", "pattern": "Cariatis"},{"label": "MIT", "pattern": "Pallas"},{"label": "MIT", "pattern": "Pandora"},{"label": "MIT", "pattern": "Elais"},{"label": "MIT", "pattern": "Itonia"},{"label": "MIT", "pattern": "Ergía"},{"label": "MIT", "pattern": "Amekhania"},{"label": "MIT", "pattern": "Ptokhenia"},{"label": "MIT", "pattern": "Penia"},{"label": "MIT", "pattern": "Anakes"},{"label": "MIT", "pattern": "Arce"},{"label": "MIT", "pattern": "Demos"},{"label": "MIT", "pattern": "Adrestia"},{"label": "MIT", "pattern": "Tritopatores"},{"label": "MIT", "pattern": "Angelia"},{"label": "MIT", "pattern": "Afeleia"},{"label": "MIT", "pattern": "Atenea Alcidemo"},{"label": "MIT", "pattern": "Pentos"},{"label": "MIT", "pattern": "Acmon"},{"label": "MIT", "pattern": "Disebia"},{"label": "MIT", "pattern": "Menae"},{"label": "MIT", "pattern": "Epiales"},{"label": "MIT", "pattern": "Epifrón"},{"label": "MIT", "pattern": "Eulabeia"},{"label": "MIT", "pattern": "Gelos"},{"label": "MIT", "pattern": "Hedylogos"},{"label": "MIT", "pattern": "Atabirio"},{"label": "MIT", "pattern": "Epidotas"},{"label": "MIT", "pattern": "Homonoeia"},{"label": "MIT", "pattern": "Helicón"},{"label": "MIT", "pattern": "Horme"},{"label": "MIT", "pattern": "Tecmor"},{"label": "MIT", "pattern": "Kakia"},{"label": "MIT", "pattern": "Kallone"},{"label": "MIT", "pattern": "Ceutonirao"},{"label": "MIT", "pattern": "Coalemo"},{"label": "MIT", "pattern": "Nomos"},{"label": "MIT", "pattern": "Manías"},{"label": "MIT", "pattern": "Pasikrata"},{"label": "MIT", "pattern": "Peitarquia"},{"label": "MIT", "pattern": "Frice"},{"label": "MIT", "pattern": "Planē"},{"label": "MIT", "pattern": "Prophasis"},{"label": "MIT", "pattern": "Pyrrhichos"}
    
            ]

ruler.add_patterns(patterns)

TRAIN_DATA = []
for sentence in corpus:
    doc = nlp(sentence)
    entities = []

    for ent in doc.ents:
        entities.append([ent.start_char, ent.end_char, ent.label_])
    TRAIN_DATA.append([sentence, {"entities": entities}])

print (TRAIN_DATA)
# Out:
# /home/gustavo/anaconda3/lib/python3.9/site-packages/spacy/util.py:887: UserWarning: [W095] Model 'es_core_news_lg' (3.3.0) was trained with spaCy v3.3 and may not be 100% compatible with the current version (3.5.3). If you see errors or degraded performance, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# ...

# %% [markdown]
# **Split data into sets for training and validation**
#
# We don’t want to use all the data for training, because that would leave us without any data to use for checking the model’s accuracy. The training data is what the model actually learns from; the validation data is the data that’s used to choose the best model from multiple training runs; the test data is the “gold standard” of “right” answers.
#
# If you read general-purpose descriptions of the different data sets for model training, you may see references to hyperparamters (like the “learning rate”). spaCy’s built-in model training provides sensible defaults that you don’t necessarily need to modify, but if you’re interested in the details of what could be modified, you can check the documentation about the training config file.

# %%
# Split the data into sets for training and validation 
from sklearn.model_selection import train_test_split
docs = TRAIN_DATA

#Split the data into the training set (90%) and validation set (10%)
train_set, validation_set = train_test_split(docs, test_size=0.1)
#Split the validation set into the actual validation set (70%) and test set (30%)
validation_set, test_set = train_test_split(validation_set, test_size=0.3)
#Print how many docs are in each set
print(f'Created {len(train_set)} training docs')
print(f'Created {len(validation_set)} validation docs')
print(f'Created {len(test_set)} test docs')
# Out:
# Created 358 training docs
# Created 28 validation docs
# Created 12 test docs

# %% [markdown]
# **Save the data sets**
# From here, we save the training, validation, and test data sets.

# %%
#Import DocBin, a format for saving a collection of spaCy Doc objects
from spacy.tokens import DocBin

def convert(lang: str, TRAIN_DATA, output_path):
    nlp = spacy.blank(lang)
    
    db = DocBin()
    for text, annot in TRAIN_DATA:
        doc = nlp.make_doc(text)
        ents = []
        for start, end, label in annot["entities"]:
            span = doc.char_span(start, end, label=label)
            if span is None:
                msg = f"Skipping entity [{start}, {end}, {label}] in the following text because the character span '{doc.text[start:end]}' does not align with token boundaries:\n\n{repr(text)}\n"
                warnings.warn(msg)
            else:
                #print("span:" + str(span) + label)
                ents.append(span)
        doc.ents = ents
        db.add(doc)
    db.to_disk(output_path)
    
    #print(train_set)
    
convert("es", train_set, "../data/train.spacy")
convert("es", validation_set, "../data/valid.spacy")
convert("es", test_set, "../data/test.spacy")

# %% [markdown]
# Making sure the files are of reasonable sizes according to how we split them (90% training, then splitting that remaining 10% into 70% validation and 30% test.)

# %%
# !ls -al ../data/train.spacy ../data/valid.spacy ../data/test.spacy
# Out:
# -rw-rw-r-- 1 gustavo gustavo  3490 jun  1 13:37 ../data/test.spacy
# -rw-rw-r-- 1 gustavo gustavo 92947 jun  1 13:37 ../data/train.spacy
# -rw-rw-r-- 1 gustavo gustavo  8227 jun  1 13:37 ../data/valid.spacy

# %% [markdown]
# **Create training configuration file**
# Here, we create the configuration file we’ll need to actually run the training. We’re using Spanish language, the named-entity recognition (NER) pipeline, and default in other options.

# %%
# !python3 -m spacy init config ./config.cfg --lang es --pipeline ner -F
# Out:
# ⚠ To generate a more effective transformer-based config (GPU-only),
# install the spacy-transformers package and re-run this command. The config
# generated now does not use transformers.
# ℹ Generated config template specific for your use case
# - Language: es
# - Pipeline: ner
# - Optimize for: efficiency
# - Hardware: CPU
# - Transformer: None
# ✔ Auto-filled config with all values
# ✔ Saved config
# config.cfg
# You can now add your data and train your pipeline:
# python -m spacy train config.cfg --paths.train ./train.spacy --paths.dev ./dev.spacy

# %% [markdown]
# **Model training**
#
# The following code starts the training. The training output goes into a directory called output, and we define the paths to the training (train.spacy) and the validation (dev.spacy) data.

# %%
# !python3 -m spacy train config.cfg --output ../output --paths.train ../data/train.spacy --paths.dev ../data/valid.spacy
# Out:
# ℹ Saving to output directory: ../output
# ℹ Using CPU
#
# =========================== Initializing pipeline ===========================
# [2023-06-01 13:37:53,842] [INFO] Set up nlp object from config
# [2023-06-01 13:37:53,855] [INFO] Pipeline: ['tok2vec', 'ner']
# [2023-06-01 13:37:53,860] [INFO] Created vocabulary
# [2023-06-01 13:37:53,861] [INFO] Finished initializing nlp object
# [2023-06-01 13:37:54,371] [INFO] Initialized pipeline components: ['tok2vec', 'ner']
# ✔ Initialized pipeline
#
# ============================= Training pipeline =============================
# ℹ Pipeline: ['tok2vec', 'ner']
# ℹ Initial learn rate: 0.001
# E    #       LOSS TOK2VEC  LOSS NER  ENTS_F  ENTS_P  ENTS_R  SCORE
# ---  ------  ------------  --------  ------  ------  ------  ------
#   0       0          0.00     66.33    0.00    0.00    0.00    0.00
#   1     200         25.70    704.11  100.00  100.00  100.00    1.00
#   4     400          4.52      8.08   95.24  100.00   90.91    0.95
# ...

# %% [markdown]
# **Test the new model**
# Finally, we can check how the model we just trained performs, using the test data set for comparison. The closer the model results are to the human-annotated test set, the better the model is performing. We’ll start with running the model on a random exerpt from the test set.

# %%
#Imports the random library to choose a random exerpt.
import random
#Displacy shows a nice visualization of spaCy data, including entities on text
from spacy import displacy 

#Load the model we just trained
new_nlp = spacy.load("../output/model-last")
#Pick a random exerpt from the test data set.
val_doc = random.choice(test_set)
#print(val_doc[0])
#Run the new model on the random exerpt
doc = new_nlp(val_doc[0])
#doc = new_nlp("a la antigua Flora y Lamia")

#Show the first 100 words of the random document.
displacy.render(doc[:100], jupyter=True, style="ent")
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Del mismo modo,
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zeus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">MIT</span>
# </mark>
#  resolvió el conflicto entre Apolo y Hércules sobre el trípode de Delfos.</div></span>

# %% [markdown]
# To compare, let’s display the original, human-generated annotations.

# %% [markdown]
# **Evaluation**
# Is the model sufficiently useful for research? What would need to be improved and changed?

# %%
# !python -m spacy evaluate ../output/model-last ../data/test.spacy --output tce.json
# Out:
# ℹ Using CPU
#
# ================================== Results ==================================
#
# TOK     100.00
# NER P   100.00
# NER R   100.00
# NER F   100.00
# SPEED   19665
#
#
# =============================== NER (per type) ===============================
#
#            P        R        F
# MIT   100.00   100.00   100.00
#
# ✔ Saved results to tce.json
